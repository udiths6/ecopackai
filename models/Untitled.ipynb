# %%
import numpy as np
import pandas as pd
import psycopg2

print("Environment ready")
# Out:
# Environment ready

# %%
import numpy as np
import pandas as pd
import psycopg2

print("Environment ready")
# Out:
# Environment ready

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database=" ecopackai",
    user="postgres",
    password="udithssql"
)

print("Connected to PostgreSQL server successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     database=" ecopackai",
#       6     user="postgres",
#       7     password="udithssql"
#       8 )
#      10 print("Connected to PostgreSQL server successfully")
#
# File D:\desktop\anaconda\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database=" ecopackai",
    user="postgres",
    password="udithssql"
)

print("Connected to PostgreSQL server successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     database=" ecopackai",
#       6     user="postgres",
#       7     password="udithssql"
#       8 )
#      10 print("Connected to PostgreSQL server successfully")
#
# File D:\desktop\anaconda\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database " ecopackai" does not exist

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database=" ecopackai",
    user="postgres",
    password="udithssql"
)

print("Connected to PostgreSQL server successfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="localhost",
#       5     database=" ecopackai",
#       6     user="postgres",
#       7     password="udithssql"
#       8 )
#      10 print("Connected to PostgreSQL server successfully")
#
# File D:\desktop\anaconda\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database " ecopackai" does not exist

# %%
import psycopg2

conn = psycopg2.connect(
    host="localhost",
    database="ecopackai",   # No leading space
    user="postgres",
    password="udithssql"
)

print("Connected to PostgreSQL server successfully")
# Out:
# Connected to PostgreSQL server successfully
